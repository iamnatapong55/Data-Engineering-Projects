# %% [markdown]
# # API request for further data analysis

# %% [markdown]
# For this project, I will use the free API found at covid19api.com that provides data on the coronavirus. I will find the total number of confirmed cases in each country and then create a pandas dataframe that contains that information. This project can be a fundamental to initiate real-time streaming with assistance of Apache Kafka and Airflow later on.

# %% [markdown]
# ## Inspecting API
# https://documenter.getpostman.com/view/10808728/SzS8rjbc?version=latest
#
# This shows us the different URLs in the API, the information they provide, and example requests/responses of those URLs on the right.

# %%
import requests

# %% [markdown]
# ## Making an HTTP Request from the API
#
# I will use the requests library to make an HTTP request from that URL and save the response object’s text under the variable response

# %%
response = requests.get('https://api.covid19api.com/summary').text

# %%
response
# JSON format
# This shows what the response is to our HTTP request from the API
# Out:
# '{"ID":"9d5c5e76-e4df-40ba-8493-aa0e619d2efd","Message":"","Global":{"NewConfirmed":1567482,"TotalConfirmed":297317194,"NewDeaths":4968,"TotalDeaths":5461498,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z"},"Countries":[{"ID":"56f9ba6a-434f-4b0f-a017-e68814f5e778","Country":"Afghanistan","CountryCode":"AF","Slug":"afghanistan","NewConfirmed":0,"TotalConfirmed":158245,"NewDeaths":0,"TotalDeaths":7367,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"a002dad6-0f35-4dc6-90e3-70ba55607c29","Country":"Albania","CountryCode":"AL","Slug":"albania","NewConfirmed":0,"TotalConfirmed":212021,"NewDeaths":0,"TotalDeaths":3224,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"51076a7c-a140-4c81-ad30-dd2f43508cd0","Country":"Algeria","CountryCode":"DZ","Slug":"algeria","NewConfirmed":0,"TotalConfirmed":220415,"NewDeaths":0,"TotalDeaths":6310,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"871ba8ed-6063-4f13-90f1-85e1f1c1b87b","Country":"Andorra","CountryCode":"AD","Slug":"andorra","NewConfirmed":0,"TotalConfirmed":25289,"NewDeaths":0,"TotalDeaths":141,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"0a097da0-c51a-4439-957c-7aea2c8a137f","Country":"Angola","CountryCode":"AO","Slug":"angola","NewConfirmed":0,"TotalConfirmed":86636,"NewDeaths":0,"TotalDeaths":1789,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"ff411e79-db2e-4633-9e60-48a750d8de9d","Country":"Antigua and Barbuda","CountryCode":"AG","Slug":"antigua-and-barbuda","NewConfirmed":0,"TotalConfirmed":4486,"NewDeaths":0,"TotalDeaths":119,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"030b944c-3c55-4dcb-83a9-c9c2d8cb5450","Country":"Argentina","CountryCode":"AR","Slug":"argentina","NewConfirmed":0,"TotalConfirmed":5915695,"NewDeaths":0,"TotalDeaths":117346,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"4d52ca31-7414-4767-9a1d-0e802b070383","Country":"Armenia","CountryCode":"AM","Slug":"armenia","NewConfirmed":0,"TotalConfirmed":345255,"NewDeaths":0,"TotalDeaths":7989,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"65fd039d-0902-460f-aaab-9bf4d749fa14","Country":"Australia","CountryCode":"AU","Slug":"australia","NewConfirmed":75426,"TotalConfirmed":684229,"NewDeaths":12,"TotalDeaths":2302,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"f1656962-1521-4153-a0ab-6d6a23e6e6ef","Country":"Austria","CountryCode":"AT","Slug":"austria","NewConfirmed":0,"TotalConfirmed":1304086,"NewDeaths":0,"TotalDeaths":13802,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"a2545368-8475-4c44-88fb-d875576e1408","Country":"Azerbaijan","CountryCode":"AZ","Slug":"azerbaijan","NewConfirmed":0,"TotalConfirmed":618918,"NewDeaths":0,"TotalDeaths":8409,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"d1616f00-6cfa-427f-a04c-640c2ff6269c","Country":"Bahamas","CountryCode":"BS","Slug":"bahamas","NewConfirmed":0,"TotalConfirmed":26326,"NewDeaths":0,"TotalDeaths":717,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"0232fac3-a77d-4261-8b68-425b9396bd60","Country":"Bahrain","CountryCode":"BH","Slug":"bahrain","NewConfirmed":0,"TotalConfirmed":286529,"NewDeaths":0,"TotalDeaths":1395,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"5e8ee522-9d3a-45b7-b2c4-a5af8137c210","Country":"Bangladesh","CountryCode":"BD","Slug":"bangladesh","NewConfirmed":0,"TotalConfirmed":1588807,"NewDeaths":0,"TotalDeaths":28090,"NewRecovered":0,"TotalRecovered":0,"Date":"2022-01-06T17:55:36.399Z","Premium":{}},{"ID":"d1d04256-d6fc-4ec0-b280-8d52033ff07b","Country":"Barbados","CountryCode ...

# %% [markdown]
# Since the response is in JSON format, we can load this string into python and convert it into a python dictionary. We first need to import the json library, and then we can use the loads method from the json library and pass it our string

# %%
#Creating a Python Dictionary
import json
response_info = json.loads(response)

# %%
response_info
# Out:
# {'ID': '9d5c5e76-e4df-40ba-8493-aa0e619d2efd',
#  'Message': '',
#  'Global': {'NewConfirmed': 1567482,
#   'TotalConfirmed': 297317194,
#   'NewDeaths': 4968,
#   'TotalDeaths': 5461498,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z'},
#  'Countries': [{'ID': '56f9ba6a-434f-4b0f-a017-e68814f5e778',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 158245,
#    'NewDeaths': 0,
#    'TotalDeaths': 7367,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a002dad6-0f35-4dc6-90e3-70ba55607c29',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 212021,
#    'NewDeaths': 0,
#    'TotalDeaths': 3224,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '51076a7c-a140-4c81-ad30-dd2f43508cd0',
#    'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 220415,
#    'NewDeaths': 0,
#    'TotalDeaths': 6310,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '871ba8ed-6063-4f13-90f1-85e1f1c1b87b',
#    'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25289,
#    'NewDeaths': 0,
#    'TotalDeaths': 141,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '0a097da0-c51a-4439-957c-7aea2c8a137f',
#    'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 86636,
#    'NewDeaths': 0,
#    'TotalDeaths': 1789,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ff411e79-db2e-4633-9e60-48a750d8de9d',
#    'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4486,
#    'NewDeaths': 0,
#    'TotalDeaths': 119,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '030b944c-3c55-4dcb-83a9-c9c2d8cb5450',
#    'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5915695,
#    'NewDeaths': 0,
#    'TotalDeaths': 117346,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4d52ca31-7414-4767-9a1d-0e802b070383',
#    'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 345255,
#    'NewDeaths': 0,
#    'TotalDeaths': 7989,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '65fd039d-0902-460f-aaab-9bf4d749fa14',
#    'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 75426,
#    'TotalConfirmed': 684229,
#    'NewDeaths': 12,
#    'TotalDeaths': 2302,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f1656962-1521-4153-a0ab-6d6a23e6e6ef',
#    'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1304086,
#    'NewDeaths': 0,
#    'TotalDeaths': 13802,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a2545368-8475-4c44-88fb-d875576e1408',
#    'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 618918,
#    'NewDeaths': 0,
#    'TotalDeaths': 8409,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'd1616f00-6cfa-427f-a04c-640c2ff6269c',
#    'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 26326,
#    'NewDeaths': 0,
#    'TotalDeaths': 717,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '0232fac3-a77d-4261-8b68-425b9396bd60',
#    'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 286529,
#    'NewDeaths': 0,
#    'TotalDeaths': 1395,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '5e8ee522-9d3a-45b7-b2c4-a5af8137c210',
#    'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1588807,
#    'NewDeaths': 0,
#    'TotalDeaths': 28090,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'd1d04256-d6fc-4ec0-b280-8d52033ff07b',
#    'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 30177,
#    'NewDeaths': 0,
#    'TotalDeaths': 263,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '89ef1d39-2642-4340-bf4e-0ee9736f9a97',
#    'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 703507,
#    'NewDeaths': 0,
#    'TotalDeaths': 5653,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '89b59e2e-9ab3-4a94-b8dd-8d1acd56e68f',
#    'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 27796,
#    'TotalConfirmed': 2179710,
#    'NewDeaths': 22,
#    'TotalDeaths': 28429,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '23d87864-aadd-4f7c-8a9f-987d3c3a602b',
#    'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 34628,
#    'NewDeaths': 0,
#    'TotalDeaths': 605,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '7dc0b7a9-716a-4c33-916b-d291715c2197',
#    'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25522,
#    'NewDeaths': 0,
#    'TotalDeaths': 161,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4041b15a-6da5-4f77-8340-adf9fee1bd5d',
#    'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2669,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '17e8de19-a8a7-4395-b92c-cf1a5672ed31',
#    'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 631554,
#    'NewDeaths': 0,
#    'TotalDeaths': 19810,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '3823ba07-e5dc-4e67-a4b0-ba8e0947cc29',
#    'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 295240,
#    'NewDeaths': 0,
#    'TotalDeaths': 13547,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ac58ac6a-5657-4973-9580-2dba66054f29',
#    'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 222053,
#    'NewDeaths': 0,
#    'TotalDeaths': 2452,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f5414a7a-0bb3-4b93-8dea-2396158ddd4a',
#    'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22328252,
#    'NewDeaths': 0,
#    'TotalDeaths': 619654,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e6a403f8-cb2d-49be-a555-70340cfc92ef',
#    'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15532,
#    'NewDeaths': 0,
#    'TotalDeaths': 98,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '12b1a700-9ddb-462d-8eed-994a6592f3ad',
#    'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 764476,
#    'NewDeaths': 0,
#    'TotalDeaths': 31303,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '2b6b8a55-1b5b-489f-b3bf-1424da3e945a',
#    'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18637,
#    'NewDeaths': 0,
#    'TotalDeaths': 333,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'c2776435-957e-465b-8d97-ca1ad34803db',
#    'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 32076,
#    'NewDeaths': 0,
#    'TotalDeaths': 38,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f23ba0c2-283b-4805-a16f-03397afd572c',
#    'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 120535,
#    'NewDeaths': 0,
#    'TotalDeaths': 3015,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e85d35d2-c1b7-4e68-a843-a376dec2f7d7',
#    'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 109367,
#    'NewDeaths': 0,
#    'TotalDeaths': 1851,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e5b5f7c9-2920-4dda-a46b-88a9ea740962',
#    'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 34229,
#    'TotalConfirmed': 2010366,
#    'NewDeaths': 79,
#    'TotalDeaths': 27247,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '89949349-6148-4442-997a-6b9ddb2807eb',
#    'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 45989,
#    'NewDeaths': 0,
#    'TotalDeaths': 356,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '1b409fce-7fef-4036-ba01-70a46d26c3f5',
#    'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12454,
#    'NewDeaths': 0,
#    'TotalDeaths': 101,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ae10622b-aba2-40a1-9931-4447c9a82d3c',
#    'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6185,
#    'NewDeaths': 0,
#    'TotalDeaths': 184,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '05a2d837-c887-4f6e-8cc4-2bf0f8f6207b',
#    'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 1840,
#    'TotalConfirmed': 1814188,
#    'NewDeaths': 3,
#    'TotalDeaths': 39177,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f9311191-799b-479e-ae9d-a38d3443d894',
#    'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 207,
#    'TotalConfirmed': 115908,
#    'NewDeaths': 0,
#    'TotalDeaths': 4849,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f77243ca-71c8-427c-bae9-054a222fc629',
#    'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 16259,
#    'TotalConfirmed': 5219633,
#    'NewDeaths': 40,
#    'TotalDeaths': 130140,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '992ead44-7721-4791-b896-98a925fd8229',
#    'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7283,
#    'NewDeaths': 0,
#    'TotalDeaths': 159,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'c68c1d29-c0fe-49ef-9e9a-8007ccacc3f3',
#    'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 21277,
#    'NewDeaths': 0,
#    'TotalDeaths': 369,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ba81ebe5-197c-4377-b267-356c3a69f75d',
#    'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 79942,
#    'NewDeaths': 0,
#    'TotalDeaths': 1225,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ca1d82c7-a8ea-4756-ad5d-9f5e96cda761',
#    'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 578413,
#    'NewDeaths': 0,
#    'TotalDeaths': 7369,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '7b758894-39a2-49ce-b0b7-8505a90d64e4',
#    'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 736486,
#    'NewDeaths': 0,
#    'TotalDeaths': 12731,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '31ed22b0-2dd0-4bd5-80cb-ea444f1b8a05',
#    'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 969138,
#    'NewDeaths': 0,
#    'TotalDeaths': 8324,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '48d4b673-9064-488c-b702-8b97df01f459',
#    'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 188380,
#    'NewDeaths': 0,
#    'TotalDeaths': 650,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '76cdb1c8-5738-450f-aac3-249fb444d3e0',
#    'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2503374,
#    'NewDeaths': 0,
#    'TotalDeaths': 36397,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f7fd43a9-d5a0-4d4b-a461-16640a489ed0',
#    'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 75064,
#    'NewDeaths': 0,
#    'TotalDeaths': 727,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f20b3bda-dbad-4197-aa76-c3b60d639f00',
#    'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 903652,
#    'NewDeaths': 0,
#    'TotalDeaths': 3338,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '3a2dde84-9bc3-41e9-b8cd-e0718ca3054d',
#    'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13839,
#    'NewDeaths': 0,
#    'TotalDeaths': 189,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '329aadd6-1b4b-4ff0-83fd-82ab195bcd44',
#    'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7073,
#    'NewDeaths': 0,
#    'TotalDeaths': 47,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '23b8ed12-ac0e-4097-9076-c2e2fd650150',
#    'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 433710,
#    'NewDeaths': 0,
#    'TotalDeaths': 4252,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a0f26edb-0420-4406-a701-66449ab32ca4',
#    'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 553201,
#    'NewDeaths': 0,
#    'TotalDeaths': 33686,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '82e0e22f-d584-43dd-8ab0-60f77777d282',
#    'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 389454,
#    'NewDeaths': 0,
#    'TotalDeaths': 21863,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f84c9ee3-9e2a-4be8-bc21-3be51779f133',
#    'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 122063,
#    'NewDeaths': 0,
#    'TotalDeaths': 3826,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e4d66566-187e-4d91-9511-288c8e282559',
#    'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13876,
#    'NewDeaths': 0,
#    'TotalDeaths': 175,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '2c969106-1f16-467f-942a-ce590696e383',
#    'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8161,
#    'NewDeaths': 0,
#    'TotalDeaths': 78,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '696900ac-4f8b-4382-91c7-7bb7a5936646',
#    'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 246221,
#    'NewDeaths': 0,
#    'TotalDeaths': 1942,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '1f7112df-2d0e-4eed-abf3-80b9ea0b8246',
#    'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 436586,
#    'NewDeaths': 0,
#    'TotalDeaths': 6988,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '54f012de-4779-44cb-b71c-0cd0b33e692f',
#    'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 55649,
#    'NewDeaths': 0,
#    'TotalDeaths': 704,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ef451a52-f42f-446e-9d75-87966066e4e1',
#    'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 289622,
#    'NewDeaths': 0,
#    'TotalDeaths': 1624,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '037de397-2bef-4357-b052-c04a59a43da9',
#    'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11027112,
#    'NewDeaths': 0,
#    'TotalDeaths': 125797,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ed3c747a-ee72-4d5d-b2ee-ba9fb7905230',
#    'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 42640,
#    'NewDeaths': 0,
#    'TotalDeaths': 290,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e9c60bc9-1e37-4780-8e15-292f60464abc',
#    'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10376,
#    'NewDeaths': 0,
#    'TotalDeaths': 343,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ef702e3d-0145-486a-9949-988e87efbbaa',
#    'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 945609,
#    'NewDeaths': 0,
#    'TotalDeaths': 14041,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '0bca1de6-7611-4179-855d-c003ee8ccea1',
#    'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 67337,
#    'TotalConfirmed': 7388045,
#    'NewDeaths': 444,
#    'TotalDeaths': 113373,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'd01f79fe-b6b9-42ab-9a59-7fe5350d81cd',
#    'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 148079,
#    'NewDeaths': 0,
#    'TotalDeaths': 1313,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'd348d838-9969-4e36-b134-8e512c320035',
#    'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1388309,
#    'NewDeaths': 0,
#    'TotalDeaths': 21115,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f6583c13-bf82-420d-b6b1-1b0f90b2bcc4',
#    'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7101,
#    'NewDeaths': 0,
#    'TotalDeaths': 200,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '5bfac20f-6af2-4347-b222-9cd74e93277c',
#    'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 631730,
#    'NewDeaths': 0,
#    'TotalDeaths': 16114,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '05a2effb-d21f-4820-8fa5-4aa2f14e072f',
#    'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33428,
#    'NewDeaths': 0,
#    'TotalDeaths': 393,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'fcc75cb9-4d39-4927-81bd-6ddf943cef9a',
#    'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6531,
#    'NewDeaths': 0,
#    'TotalDeaths': 149,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'eb321ca8-6d53-47d0-85b1-e5c6ebf874f5',
#    'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 41418,
#    'NewDeaths': 0,
#    'TotalDeaths': 1060,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'fd40832b-c0aa-4fcf-9cc7-ed1b228c45f5',
#    'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 26259,
#    'NewDeaths': 0,
#    'TotalDeaths': 774,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'b8bb3249-fb08-4ceb-8652-3902473f6942',
#    'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '049177f1-7e11-4352-b4f1-63b6f28c9bbd',
#    'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 379402,
#    'NewDeaths': 0,
#    'TotalDeaths': 10433,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '7b945ce2-4fde-407c-82ee-eae8deced102',
#    'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1269979,
#    'NewDeaths': 0,
#    'TotalDeaths': 39599,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ddbd635e-42f1-49d8-a325-d60abd42a0d6',
#    'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33901,
#    'NewDeaths': 0,
#    'TotalDeaths': 39,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'd5d6929f-7252-427f-ad9c-435376b2d3c0',
#    'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 90928,
#    'TotalConfirmed': 35109286,
#    'NewDeaths': 325,
#    'TotalDeaths': 482876,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '0faca8ec-8e87-448c-af83-9d4f5b8a0d93',
#    'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4264136,
#    'NewDeaths': 0,
#    'TotalDeaths': 144109,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '8267f2f3-d51f-4a4c-b107-b7b2bbb8e5c1',
#    'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6201467,
#    'NewDeaths': 0,
#    'TotalDeaths': 131778,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '0d35b164-c3c9-4dd4-9895-eb8f5bb5529f',
#    'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2095183,
#    'NewDeaths': 0,
#    'TotalDeaths': 24191,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4d9badcc-5706-44d5-a29d-888606c2ef99',
#    'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 884855,
#    'NewDeaths': 0,
#    'TotalDeaths': 5952,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'eef6ee11-bafd-44a1-bcdb-ee52b6c96878',
#    'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1429030,
#    'NewDeaths': 0,
#    'TotalDeaths': 8253,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f852b690-b567-448a-b590-d75e8924749c',
#    'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 189088,
#    'TotalConfirmed': 6756035,
#    'NewDeaths': 231,
#    'TotalDeaths': 138276,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '8d8b6317-f286-4f6a-9b41-62f2317d8c47',
#    'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 97066,
#    'NewDeaths': 0,
#    'TotalDeaths': 2483,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '03e0437f-0a30-46e3-97c2-c0530ae957c5',
#    'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 2490,
#    'TotalConfirmed': 1737540,
#    'NewDeaths': 1,
#    'TotalDeaths': 18394,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '3b769e50-0c4f-41da-b4bf-0cc91efcccb3',
#    'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1047953,
#    'NewDeaths': 0,
#    'TotalDeaths': 12372,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'b807dc80-263a-4c73-a6c8-fc89a92b6884',
#    'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1074283,
#    'NewDeaths': 0,
#    'TotalDeaths': 18267,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '1204ca00-fda7-4d73-8e08-7beb612e6c5b',
#    'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 304350,
#    'NewDeaths': 0,
#    'TotalDeaths': 5404,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '6661b505-bd74-421f-ad07-958afa3f829f',
#    'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '23dae1a1-1430-432d-b071-df60834584f9',
#    'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 653792,
#    'NewDeaths': 0,
#    'TotalDeaths': 5887,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ebccb6a4-2a54-4390-912b-0c1a64169e0f',
#    'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 423042,
#    'NewDeaths': 0,
#    'TotalDeaths': 2469,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '1c7124c2-2088-4a8e-8ec0-008be7621c99',
#    'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 185031,
#    'NewDeaths': 0,
#    'TotalDeaths': 2809,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4dbef75b-bf7c-424d-ab6f-d0b8f3056cc9',
#    'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 114787,
#    'NewDeaths': 0,
#    'TotalDeaths': 409,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'cd7b11af-dc84-4c51-8be0-4ade80eff125',
#    'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 281155,
#    'NewDeaths': 0,
#    'TotalDeaths': 4613,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '424a7399-a80e-48b4-90ea-8e6da1213cde',
#    'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 746632,
#    'NewDeaths': 0,
#    'TotalDeaths': 9213,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '82508303-3837-40c9-a2ad-76eac4f9e0f6',
#    'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29999,
#    'NewDeaths': 0,
#    'TotalDeaths': 673,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '6d109350-2647-49e8-a003-d5e689c210ce',
#    'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6851,
#    'NewDeaths': 0,
#    'TotalDeaths': 287,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e9dd4098-99a6-4c54-9d70-b363a101c3ca',
#    'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 391633,
#    'NewDeaths': 0,
#    'TotalDeaths': 5752,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '8b4fded2-3ac0-454d-af4e-ab2ecbefa6a1',
#    'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6406,
#    'NewDeaths': 0,
#    'TotalDeaths': 71,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '85cac20e-dd06-46a8-8f0b-93e9b907c227',
#    'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 529540,
#    'NewDeaths': 0,
#    'TotalDeaths': 7475,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '5cac88c3-cb81-4255-bb48-966ff38b49ae',
#    'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 108366,
#    'NewDeaths': 0,
#    'TotalDeaths': 920,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4918b52f-bf4c-4bca-8a88-668a38b83127',
#    'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 228540,
#    'NewDeaths': 0,
#    'TotalDeaths': 8000,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'fb50a7d8-7f35-4a6a-adee-0470b6c14461',
#    'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 52434,
#    'NewDeaths': 0,
#    'TotalDeaths': 1067,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '8ecc2051-c034-493d-8421-a9b587d281b9',
#    'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 77629,
#    'NewDeaths': 0,
#    'TotalDeaths': 2395,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '7674f0c6-5ee3-4560-88f5-b259a0100a6e',
#    'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 3270,
#    'TotalConfirmed': 2773156,
#    'NewDeaths': 18,
#    'TotalDeaths': 31609,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '35d37c66-8977-4565-95b4-ceddc914f91b',
#    'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 96746,
#    'NewDeaths': 0,
#    'TotalDeaths': 263,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '778b44f5-eb24-4903-bf2f-55410dd6ba31',
#    'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22834,
#    'NewDeaths': 0,
#    'TotalDeaths': 670,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '43a9209e-2986-4809-8102-a5cc2601a5fd',
#    'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 57131,
#    'NewDeaths': 0,
#    'TotalDeaths': 482,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a3c8297d-191a-4d13-b62e-fe7d31576c77',
#    'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '7cc30230-1ba8-4825-bd69-8a4edf2dff29',
#    'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 44646,
#    'NewDeaths': 0,
#    'TotalDeaths': 876,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'bf80279b-c340-4548-892c-a463c7c676fe',
#    'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23602,
#    'NewDeaths': 0,
#    'TotalDeaths': 240,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '110240d6-3af7-4f36-b4ad-e2275fa08c0b',
#    'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 20626,
#    'TotalConfirmed': 4029274,
#    'NewDeaths': 131,
#    'TotalDeaths': 299842,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '27527db3-0d6c-411d-9bdb-263d5d61d9f7',
#    'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '9f9f56f1-46f9-42c3-ad70-66d55d96481f',
#    'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 378202,
#    'NewDeaths': 0,
#    'TotalDeaths': 10328,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a019ede2-6b51-4798-835a-b505b1698d91',
#    'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5492,
#    'NewDeaths': 0,
#    'TotalDeaths': 41,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ce924794-50c4-4589-b581-7e9b22c803b0',
#    'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 391657,
#    'NewDeaths': 0,
#    'TotalDeaths': 2067,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '39e7d99a-f05e-48a3-8673-a7df414d788a',
#    'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 180260,
#    'NewDeaths': 0,
#    'TotalDeaths': 2428,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '14b9e2e0-51e2-47cb-b67c-a31ed9559e0b',
#    'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 977579,
#    'NewDeaths': 0,
#    'TotalDeaths': 14872,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'adc02423-0c1a-41e7-81fc-0ed88e5ab054',
#    'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 199940,
#    'NewDeaths': 0,
#    'TotalDeaths': 2050,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'd0d77b58-0b96-4257-bd2f-b4512e1d8cec',
#    'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 531432,
#    'NewDeaths': 0,
#    'TotalDeaths': 19282,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e0ee1cd1-cbbf-4509-8b56-64ba8f7b16ac',
#    'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 150540,
#    'NewDeaths': 0,
#    'TotalDeaths': 3672,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'b13c876a-334f-4144-8d8e-f31b23ce4b52',
#    'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 830002,
#    'NewDeaths': 0,
#    'TotalDeaths': 11601,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4cc6e969-bee6-4292-98d4-17d9a82d5916',
#    'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 24490,
#    'TotalConfirmed': 3223325,
#    'NewDeaths': 39,
#    'TotalDeaths': 21029,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4eb50ef2-1f9c-4e09-8952-0c818ec5fb55',
#    'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14469,
#    'NewDeaths': 0,
#    'TotalDeaths': 51,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'fa688a36-8645-4321-a886-6d38249297e4',
#    'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17526,
#    'NewDeaths': 0,
#    'TotalDeaths': 218,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'de151caa-0e82-46bb-9ad7-1b68d30cf2d9',
#    'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7590,
#    'NewDeaths': 0,
#    'TotalDeaths': 277,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'c59b6a2c-f047-4607-80fd-94df6fbf38f3',
#    'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 245404,
#    'NewDeaths': 0,
#    'TotalDeaths': 3058,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '5bf4b634-7a85-42bc-846e-f04ec523cfd6',
#    'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 420857,
#    'NewDeaths': 0,
#    'TotalDeaths': 1349,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'c8f0820e-bc4e-48f1-9fdb-129cb0c01b0a',
#    'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 306492,
#    'NewDeaths': 0,
#    'TotalDeaths': 4117,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '8ca45152-d137-4e61-9849-59cf649de0bd',
#    'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 1085,
#    'TotalConfirmed': 1299848,
#    'NewDeaths': 5,
#    'TotalDeaths': 28955,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '07880336-dce9-4705-b295-13b5684894ad',
#    'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '960421cd-6817-4095-8c47-7e76eeae98e9',
#    'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 471414,
#    'NewDeaths': 0,
#    'TotalDeaths': 4954,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '3a0bd492-e75d-47b0-bb71-16718ee8d2e0',
#    'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 503407,
#    'NewDeaths': 0,
#    'TotalDeaths': 7445,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '7a1081a2-0ce9-460a-af93-069e18e12e37',
#    'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 36196,
#    'NewDeaths': 0,
#    'TotalDeaths': 590,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4e9d9105-ed3c-4133-aa26-50d9ddccbd44',
#    'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 471434,
#    'NewDeaths': 0,
#    'TotalDeaths': 16653,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'c923bee8-9e06-473e-8bcc-fb660b213039',
#    'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2309856,
#    'NewDeaths': 0,
#    'TotalDeaths': 202867,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '029189a9-b5c9-4a79-83e2-fc3fc091688d',
#    'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2871745,
#    'NewDeaths': 0,
#    'TotalDeaths': 51662,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '61856f6e-d9dd-4b90-a43a-c3e9348fbf59',
#    'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4162715,
#    'NewDeaths': 0,
#    'TotalDeaths': 98666,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '1e246f23-9863-4cde-9e9b-40ce3fcf414c',
#    'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1499976,
#    'NewDeaths': 0,
#    'TotalDeaths': 19029,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '9223faf8-7326-43c2-a9b8-47507dd7b5de',
#    'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 257504,
#    'NewDeaths': 0,
#    'TotalDeaths': 618,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'abb716aa-319f-4627-aade-bfde4dd88c03',
#    'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 161813,
#    'NewDeaths': 0,
#    'TotalDeaths': 2991,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '1137942d-bb76-4135-bf41-48127c7352fb',
#    'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1821849,
#    'NewDeaths': 0,
#    'TotalDeaths': 58896,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '01960a55-66e7-4e82-bb16-903120f38cbd',
#    'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 15632,
#    'TotalConfirmed': 10405684,
#    'NewDeaths': 804,
#    'TotalDeaths': 306710,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'da38ccbb-7676-41df-8b30-942460ac2303',
#    'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 117123,
#    'NewDeaths': 0,
#    'TotalDeaths': 1362,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '8f6b1527-f912-41cc-93e5-5e3d2f913369',
#    'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3489,
#    'NewDeaths': 0,
#    'TotalDeaths': 28,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'c085e510-a14d-4050-ad03-a36258818eb4',
#    'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13974,
#    'NewDeaths': 0,
#    'TotalDeaths': 305,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a4a1005a-df8a-4e3f-af8c-ab1d8db67de7',
#    'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6039,
#    'NewDeaths': 0,
#    'TotalDeaths': 83,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '977182e4-3eb4-4807-87e5-298c96c07105',
#    'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '577e1b9e-f310-4ca5-9e9a-c96c5bc38327',
#    'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8847,
#    'NewDeaths': 0,
#    'TotalDeaths': 103,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '572c36f6-fd13-443c-a499-90bf6a55ea23',
#    'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4034,
#    'NewDeaths': 0,
#    'TotalDeaths': 61,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a91d3924-8b6c-4b65-ae31-3157d3a9d13e',
#    'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 565482,
#    'NewDeaths': 0,
#    'TotalDeaths': 8886,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e60620a4-837d-4111-9de0-262b0cd1c160',
#    'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 76753,
#    'NewDeaths': 0,
#    'TotalDeaths': 1892,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '76af6df9-f55c-48ec-9496-0dd3a937eeb3',
#    'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1318333,
#    'NewDeaths': 0,
#    'TotalDeaths': 12831,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a55ccb52-c8b4-479c-a435-1c4478c9db61',
#    'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 26255,
#    'NewDeaths': 0,
#    'TotalDeaths': 134,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '8e045411-e793-405f-97b7-0122750955a3',
#    'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7308,
#    'NewDeaths': 0,
#    'TotalDeaths': 123,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a4ec628c-4ea7-47ec-89b6-15e25825685a',
#    'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 282401,
#    'NewDeaths': 0,
#    'TotalDeaths': 834,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'daa48f11-5cb8-4f3b-9c6f-d07899f6fa37',
#    'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1385760,
#    'NewDeaths': 0,
#    'TotalDeaths': 16824,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '7bf94a45-b726-4121-8856-f395ad3be7a4',
#    'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 475027,
#    'NewDeaths': 0,
#    'TotalDeaths': 5629,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a0275801-78db-4a94-8aa7-3026a6236c22',
#    'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'b2a80fdf-bb08-4c1c-ae9b-69cc60249c64',
#    'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24261,
#    'NewDeaths': 0,
#    'TotalDeaths': 1335,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a70c9030-cb6e-47a7-80b9-b1a0cb097504',
#    'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3494696,
#    'NewDeaths': 0,
#    'TotalDeaths': 91561,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '05274dbf-4065-450c-8905-025c51631818',
#    'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15849,
#    'NewDeaths': 0,
#    'TotalDeaths': 136,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '3b4739b5-c9ee-4357-8c98-83a160984ed9',
#    'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 137180,
#    'TotalConfirmed': 6922466,
#    'NewDeaths': 148,
#    'TotalDeaths': 89837,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '0925f578-df88-4c8d-9b5e-a5d3673bff80',
#    'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 589479,
#    'NewDeaths': 0,
#    'TotalDeaths': 15065,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ede99604-7c45-4365-ba3b-744c5a19b33a',
#    'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 47272,
#    'NewDeaths': 0,
#    'TotalDeaths': 3340,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e73aac2f-6f19-4252-8892-5e3ead291b17',
#    'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 55376,
#    'NewDeaths': 0,
#    'TotalDeaths': 1193,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '82e13276-cba2-459b-a659-03659ab7a796',
#    'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 66873,
#    'NewDeaths': 0,
#    'TotalDeaths': 1320,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e3dfc40a-3f3d-4723-8330-07f86b1b3994',
#    'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 17514,
#    'TotalConfirmed': 1375267,
#    'NewDeaths': 39,
#    'TotalDeaths': 15369,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a4124ece-2229-4746-acb1-688cccec6dee',
#    'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1422932,
#    'NewDeaths': 0,
#    'TotalDeaths': 12303,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '1a4269a3-d7e4-49e1-94f6-55e73f08e0cf',
#    'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 50417,
#    'NewDeaths': 0,
#    'TotalDeaths': 2915,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '1680e2a9-8754-4802-bb4f-a6bfc1807465',
#    'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17155,
#    'NewDeaths': 0,
#    'TotalDeaths': 850,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '7443bbef-21dd-4f49-93d9-72f9b84d48a0',
#    'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17493,
#    'NewDeaths': 0,
#    'TotalDeaths': 125,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4eaf5eae-7c5a-4781-a289-f1de56e00618',
#    'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 30564,
#    'NewDeaths': 0,
#    'TotalDeaths': 740,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '3c41a9b5-deff-4147-b900-33d128d9d6ab',
#    'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2235576,
#    'NewDeaths': 0,
#    'TotalDeaths': 21750,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'd9ead2a0-9955-4866-b683-3a9128b45ff6',
#    'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19842,
#    'NewDeaths': 0,
#    'TotalDeaths': 122,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'ec8cfe90-3dd0-411b-8d8a-ef25d457b2f7',
#    'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 32515,
#    'NewDeaths': 0,
#    'TotalDeaths': 251,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '3a68069e-2cbd-49b8-9252-177d4f0a2bc9',
#    'Country': 'Tonga',
#    'CountryCode': 'TO',
#    'Slug': 'tonga',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4d6ebc5d-a8b4-4e00-89bd-61f658c4d837',
#    'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 94213,
#    'NewDeaths': 0,
#    'TotalDeaths': 2973,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '4a2f2821-a9ca-4f70-b53d-99cf10f3b451',
#    'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 733379,
#    'NewDeaths': 0,
#    'TotalDeaths': 25617,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'a9f567a8-d3ed-48f5-b4d7-977637bada38',
#    'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9720831,
#    'NewDeaths': 0,
#    'TotalDeaths': 83075,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'e8f454e0-bbf5-445f-96b8-509a4cbb17bb',
#    'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 148609,
#    'NewDeaths': 0,
#    'TotalDeaths': 3313,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'f8b39b96-4ee7-4523-a255-3df7bd3c3946',
#    'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 4711,
#    'TotalConfirmed': 3862959,
#    'NewDeaths': 297,
#    'TotalDeaths': 103014,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '29242946-6d9a-42ed-8b34-9253af9d1887',
#    'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 774897,
#    'NewDeaths': 0,
#    'TotalDeaths': 2170,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '934ff0fa-6a52-4144-8544-766d70165b9a',
#    'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 195235,
#    'TotalConfirmed': 13918510,
#    'NewDeaths': 344,
#    'TotalDeaths': 149761,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '522b0b28-db35-4183-8ab5-10fce095ea9f',
#    'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 642139,
#    'TotalConfirmed': 57700873,
#    'NewDeaths': 1986,
#    'TotalDeaths': 832118,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '8bcd3bf9-5ade-4ae8-8983-ee6d23766e89',
#    'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 425436,
#    'NewDeaths': 0,
#    'TotalDeaths': 6181,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'd88c0b38-613c-4b01-a017-015c48166ad2',
#    'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 199361,
#    'NewDeaths': 0,
#    'TotalDeaths': 1485,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '079375f7-fb0b-4166-b1bd-5f830ea57ad3',
#    'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'dc9c2457-b1c9-4dd4-b2cc-99915dfacb34',
#    'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 445680,
#    'NewDeaths': 0,
#    'TotalDeaths': 5341,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': 'dca40048-729d-4a86-8844-a693d47a0c99',
#    'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1817721,
#    'NewDeaths': 0,
#    'TotalDeaths': 33475,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '88e3c666-f05b-412a-934b-cee4040ef1f8',
#    'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10146,
#    'NewDeaths': 0,
#    'TotalDeaths': 1985,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '80290efe-990a-4a0f-a6e5-88a8e892a4cd',
#    'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 269991,
#    'NewDeaths': 0,
#    'TotalDeaths': 3772,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}},
#   {'ID': '71b790f9-4642-4654-8938-fb91290ca601',
#    'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 219057,
#    'NewDeaths': 0,
#    'TotalDeaths': 5092,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2022-01-06T17:55:36.399Z',
#    'Premium': {}}],
#  'Date': '2022-01-06T17:55:36.399Z'}

# %%
type(response_info)
# Out:
# dict

# %%
response_info['Countries']
# Out:
# [{'ID': '56f9ba6a-434f-4b0f-a017-e68814f5e778',
#   'Country': 'Afghanistan',
#   'CountryCode': 'AF',
#   'Slug': 'afghanistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 158245,
#   'NewDeaths': 0,
#   'TotalDeaths': 7367,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a002dad6-0f35-4dc6-90e3-70ba55607c29',
#   'Country': 'Albania',
#   'CountryCode': 'AL',
#   'Slug': 'albania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 212021,
#   'NewDeaths': 0,
#   'TotalDeaths': 3224,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '51076a7c-a140-4c81-ad30-dd2f43508cd0',
#   'Country': 'Algeria',
#   'CountryCode': 'DZ',
#   'Slug': 'algeria',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 220415,
#   'NewDeaths': 0,
#   'TotalDeaths': 6310,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '871ba8ed-6063-4f13-90f1-85e1f1c1b87b',
#   'Country': 'Andorra',
#   'CountryCode': 'AD',
#   'Slug': 'andorra',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 25289,
#   'NewDeaths': 0,
#   'TotalDeaths': 141,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '0a097da0-c51a-4439-957c-7aea2c8a137f',
#   'Country': 'Angola',
#   'CountryCode': 'AO',
#   'Slug': 'angola',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 86636,
#   'NewDeaths': 0,
#   'TotalDeaths': 1789,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ff411e79-db2e-4633-9e60-48a750d8de9d',
#   'Country': 'Antigua and Barbuda',
#   'CountryCode': 'AG',
#   'Slug': 'antigua-and-barbuda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4486,
#   'NewDeaths': 0,
#   'TotalDeaths': 119,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '030b944c-3c55-4dcb-83a9-c9c2d8cb5450',
#   'Country': 'Argentina',
#   'CountryCode': 'AR',
#   'Slug': 'argentina',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5915695,
#   'NewDeaths': 0,
#   'TotalDeaths': 117346,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4d52ca31-7414-4767-9a1d-0e802b070383',
#   'Country': 'Armenia',
#   'CountryCode': 'AM',
#   'Slug': 'armenia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 345255,
#   'NewDeaths': 0,
#   'TotalDeaths': 7989,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '65fd039d-0902-460f-aaab-9bf4d749fa14',
#   'Country': 'Australia',
#   'CountryCode': 'AU',
#   'Slug': 'australia',
#   'NewConfirmed': 75426,
#   'TotalConfirmed': 684229,
#   'NewDeaths': 12,
#   'TotalDeaths': 2302,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f1656962-1521-4153-a0ab-6d6a23e6e6ef',
#   'Country': 'Austria',
#   'CountryCode': 'AT',
#   'Slug': 'austria',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1304086,
#   'NewDeaths': 0,
#   'TotalDeaths': 13802,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a2545368-8475-4c44-88fb-d875576e1408',
#   'Country': 'Azerbaijan',
#   'CountryCode': 'AZ',
#   'Slug': 'azerbaijan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 618918,
#   'NewDeaths': 0,
#   'TotalDeaths': 8409,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'd1616f00-6cfa-427f-a04c-640c2ff6269c',
#   'Country': 'Bahamas',
#   'CountryCode': 'BS',
#   'Slug': 'bahamas',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 26326,
#   'NewDeaths': 0,
#   'TotalDeaths': 717,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '0232fac3-a77d-4261-8b68-425b9396bd60',
#   'Country': 'Bahrain',
#   'CountryCode': 'BH',
#   'Slug': 'bahrain',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 286529,
#   'NewDeaths': 0,
#   'TotalDeaths': 1395,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '5e8ee522-9d3a-45b7-b2c4-a5af8137c210',
#   'Country': 'Bangladesh',
#   'CountryCode': 'BD',
#   'Slug': 'bangladesh',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1588807,
#   'NewDeaths': 0,
#   'TotalDeaths': 28090,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'd1d04256-d6fc-4ec0-b280-8d52033ff07b',
#   'Country': 'Barbados',
#   'CountryCode': 'BB',
#   'Slug': 'barbados',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 30177,
#   'NewDeaths': 0,
#   'TotalDeaths': 263,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '89ef1d39-2642-4340-bf4e-0ee9736f9a97',
#   'Country': 'Belarus',
#   'CountryCode': 'BY',
#   'Slug': 'belarus',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 703507,
#   'NewDeaths': 0,
#   'TotalDeaths': 5653,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '89b59e2e-9ab3-4a94-b8dd-8d1acd56e68f',
#   'Country': 'Belgium',
#   'CountryCode': 'BE',
#   'Slug': 'belgium',
#   'NewConfirmed': 27796,
#   'TotalConfirmed': 2179710,
#   'NewDeaths': 22,
#   'TotalDeaths': 28429,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '23d87864-aadd-4f7c-8a9f-987d3c3a602b',
#   'Country': 'Belize',
#   'CountryCode': 'BZ',
#   'Slug': 'belize',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 34628,
#   'NewDeaths': 0,
#   'TotalDeaths': 605,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '7dc0b7a9-716a-4c33-916b-d291715c2197',
#   'Country': 'Benin',
#   'CountryCode': 'BJ',
#   'Slug': 'benin',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 25522,
#   'NewDeaths': 0,
#   'TotalDeaths': 161,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4041b15a-6da5-4f77-8340-adf9fee1bd5d',
#   'Country': 'Bhutan',
#   'CountryCode': 'BT',
#   'Slug': 'bhutan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2669,
#   'NewDeaths': 0,
#   'TotalDeaths': 3,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '17e8de19-a8a7-4395-b92c-cf1a5672ed31',
#   'Country': 'Bolivia',
#   'CountryCode': 'BO',
#   'Slug': 'bolivia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 631554,
#   'NewDeaths': 0,
#   'TotalDeaths': 19810,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '3823ba07-e5dc-4e67-a4b0-ba8e0947cc29',
#   'Country': 'Bosnia and Herzegovina',
#   'CountryCode': 'BA',
#   'Slug': 'bosnia-and-herzegovina',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 295240,
#   'NewDeaths': 0,
#   'TotalDeaths': 13547,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ac58ac6a-5657-4973-9580-2dba66054f29',
#   'Country': 'Botswana',
#   'CountryCode': 'BW',
#   'Slug': 'botswana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 222053,
#   'NewDeaths': 0,
#   'TotalDeaths': 2452,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f5414a7a-0bb3-4b93-8dea-2396158ddd4a',
#   'Country': 'Brazil',
#   'CountryCode': 'BR',
#   'Slug': 'brazil',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 22328252,
#   'NewDeaths': 0,
#   'TotalDeaths': 619654,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e6a403f8-cb2d-49be-a555-70340cfc92ef',
#   'Country': 'Brunei Darussalam',
#   'CountryCode': 'BN',
#   'Slug': 'brunei',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15532,
#   'NewDeaths': 0,
#   'TotalDeaths': 98,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '12b1a700-9ddb-462d-8eed-994a6592f3ad',
#   'Country': 'Bulgaria',
#   'CountryCode': 'BG',
#   'Slug': 'bulgaria',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 764476,
#   'NewDeaths': 0,
#   'TotalDeaths': 31303,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '2b6b8a55-1b5b-489f-b3bf-1424da3e945a',
#   'Country': 'Burkina Faso',
#   'CountryCode': 'BF',
#   'Slug': 'burkina-faso',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 18637,
#   'NewDeaths': 0,
#   'TotalDeaths': 333,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'c2776435-957e-465b-8d97-ca1ad34803db',
#   'Country': 'Burundi',
#   'CountryCode': 'BI',
#   'Slug': 'burundi',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 32076,
#   'NewDeaths': 0,
#   'TotalDeaths': 38,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f23ba0c2-283b-4805-a16f-03397afd572c',
#   'Country': 'Cambodia',
#   'CountryCode': 'KH',
#   'Slug': 'cambodia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 120535,
#   'NewDeaths': 0,
#   'TotalDeaths': 3015,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e85d35d2-c1b7-4e68-a843-a376dec2f7d7',
#   'Country': 'Cameroon',
#   'CountryCode': 'CM',
#   'Slug': 'cameroon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 109367,
#   'NewDeaths': 0,
#   'TotalDeaths': 1851,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e5b5f7c9-2920-4dda-a46b-88a9ea740962',
#   'Country': 'Canada',
#   'CountryCode': 'CA',
#   'Slug': 'canada',
#   'NewConfirmed': 34229,
#   'TotalConfirmed': 2010366,
#   'NewDeaths': 79,
#   'TotalDeaths': 27247,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '89949349-6148-4442-997a-6b9ddb2807eb',
#   'Country': 'Cape Verde',
#   'CountryCode': 'CV',
#   'Slug': 'cape-verde',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 45989,
#   'NewDeaths': 0,
#   'TotalDeaths': 356,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '1b409fce-7fef-4036-ba01-70a46d26c3f5',
#   'Country': 'Central African Republic',
#   'CountryCode': 'CF',
#   'Slug': 'central-african-republic',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 12454,
#   'NewDeaths': 0,
#   'TotalDeaths': 101,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ae10622b-aba2-40a1-9931-4447c9a82d3c',
#   'Country': 'Chad',
#   'CountryCode': 'TD',
#   'Slug': 'chad',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6185,
#   'NewDeaths': 0,
#   'TotalDeaths': 184,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '05a2d837-c887-4f6e-8cc4-2bf0f8f6207b',
#   'Country': 'Chile',
#   'CountryCode': 'CL',
#   'Slug': 'chile',
#   'NewConfirmed': 1840,
#   'TotalConfirmed': 1814188,
#   'NewDeaths': 3,
#   'TotalDeaths': 39177,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f9311191-799b-479e-ae9d-a38d3443d894',
#   'Country': 'China',
#   'CountryCode': 'CN',
#   'Slug': 'china',
#   'NewConfirmed': 207,
#   'TotalConfirmed': 115908,
#   'NewDeaths': 0,
#   'TotalDeaths': 4849,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f77243ca-71c8-427c-bae9-054a222fc629',
#   'Country': 'Colombia',
#   'CountryCode': 'CO',
#   'Slug': 'colombia',
#   'NewConfirmed': 16259,
#   'TotalConfirmed': 5219633,
#   'NewDeaths': 40,
#   'TotalDeaths': 130140,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '992ead44-7721-4791-b896-98a925fd8229',
#   'Country': 'Comoros',
#   'CountryCode': 'KM',
#   'Slug': 'comoros',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7283,
#   'NewDeaths': 0,
#   'TotalDeaths': 159,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'c68c1d29-c0fe-49ef-9e9a-8007ccacc3f3',
#   'Country': 'Congo (Brazzaville)',
#   'CountryCode': 'CG',
#   'Slug': 'congo-brazzaville',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 21277,
#   'NewDeaths': 0,
#   'TotalDeaths': 369,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ba81ebe5-197c-4377-b267-356c3a69f75d',
#   'Country': 'Congo (Kinshasa)',
#   'CountryCode': 'CD',
#   'Slug': 'congo-kinshasa',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 79942,
#   'NewDeaths': 0,
#   'TotalDeaths': 1225,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ca1d82c7-a8ea-4756-ad5d-9f5e96cda761',
#   'Country': 'Costa Rica',
#   'CountryCode': 'CR',
#   'Slug': 'costa-rica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 578413,
#   'NewDeaths': 0,
#   'TotalDeaths': 7369,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '7b758894-39a2-49ce-b0b7-8505a90d64e4',
#   'Country': 'Croatia',
#   'CountryCode': 'HR',
#   'Slug': 'croatia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 736486,
#   'NewDeaths': 0,
#   'TotalDeaths': 12731,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '31ed22b0-2dd0-4bd5-80cb-ea444f1b8a05',
#   'Country': 'Cuba',
#   'CountryCode': 'CU',
#   'Slug': 'cuba',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 969138,
#   'NewDeaths': 0,
#   'TotalDeaths': 8324,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '48d4b673-9064-488c-b702-8b97df01f459',
#   'Country': 'Cyprus',
#   'CountryCode': 'CY',
#   'Slug': 'cyprus',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 188380,
#   'NewDeaths': 0,
#   'TotalDeaths': 650,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '76cdb1c8-5738-450f-aac3-249fb444d3e0',
#   'Country': 'Czech Republic',
#   'CountryCode': 'CZ',
#   'Slug': 'czech-republic',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2503374,
#   'NewDeaths': 0,
#   'TotalDeaths': 36397,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f7fd43a9-d5a0-4d4b-a461-16640a489ed0',
#   'Country': "Côte d'Ivoire",
#   'CountryCode': 'CI',
#   'Slug': 'cote-divoire',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 75064,
#   'NewDeaths': 0,
#   'TotalDeaths': 727,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f20b3bda-dbad-4197-aa76-c3b60d639f00',
#   'Country': 'Denmark',
#   'CountryCode': 'DK',
#   'Slug': 'denmark',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 903652,
#   'NewDeaths': 0,
#   'TotalDeaths': 3338,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '3a2dde84-9bc3-41e9-b8cd-e0718ca3054d',
#   'Country': 'Djibouti',
#   'CountryCode': 'DJ',
#   'Slug': 'djibouti',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 13839,
#   'NewDeaths': 0,
#   'TotalDeaths': 189,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '329aadd6-1b4b-4ff0-83fd-82ab195bcd44',
#   'Country': 'Dominica',
#   'CountryCode': 'DM',
#   'Slug': 'dominica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7073,
#   'NewDeaths': 0,
#   'TotalDeaths': 47,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '23b8ed12-ac0e-4097-9076-c2e2fd650150',
#   'Country': 'Dominican Republic',
#   'CountryCode': 'DO',
#   'Slug': 'dominican-republic',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 433710,
#   'NewDeaths': 0,
#   'TotalDeaths': 4252,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a0f26edb-0420-4406-a701-66449ab32ca4',
#   'Country': 'Ecuador',
#   'CountryCode': 'EC',
#   'Slug': 'ecuador',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 553201,
#   'NewDeaths': 0,
#   'TotalDeaths': 33686,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '82e0e22f-d584-43dd-8ab0-60f77777d282',
#   'Country': 'Egypt',
#   'CountryCode': 'EG',
#   'Slug': 'egypt',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 389454,
#   'NewDeaths': 0,
#   'TotalDeaths': 21863,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f84c9ee3-9e2a-4be8-bc21-3be51779f133',
#   'Country': 'El Salvador',
#   'CountryCode': 'SV',
#   'Slug': 'el-salvador',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 122063,
#   'NewDeaths': 0,
#   'TotalDeaths': 3826,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e4d66566-187e-4d91-9511-288c8e282559',
#   'Country': 'Equatorial Guinea',
#   'CountryCode': 'GQ',
#   'Slug': 'equatorial-guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 13876,
#   'NewDeaths': 0,
#   'TotalDeaths': 175,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '2c969106-1f16-467f-942a-ce590696e383',
#   'Country': 'Eritrea',
#   'CountryCode': 'ER',
#   'Slug': 'eritrea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8161,
#   'NewDeaths': 0,
#   'TotalDeaths': 78,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '696900ac-4f8b-4382-91c7-7bb7a5936646',
#   'Country': 'Estonia',
#   'CountryCode': 'EE',
#   'Slug': 'estonia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 246221,
#   'NewDeaths': 0,
#   'TotalDeaths': 1942,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '1f7112df-2d0e-4eed-abf3-80b9ea0b8246',
#   'Country': 'Ethiopia',
#   'CountryCode': 'ET',
#   'Slug': 'ethiopia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 436586,
#   'NewDeaths': 0,
#   'TotalDeaths': 6988,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '54f012de-4779-44cb-b71c-0cd0b33e692f',
#   'Country': 'Fiji',
#   'CountryCode': 'FJ',
#   'Slug': 'fiji',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 55649,
#   'NewDeaths': 0,
#   'TotalDeaths': 704,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ef451a52-f42f-446e-9d75-87966066e4e1',
#   'Country': 'Finland',
#   'CountryCode': 'FI',
#   'Slug': 'finland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 289622,
#   'NewDeaths': 0,
#   'TotalDeaths': 1624,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '037de397-2bef-4357-b052-c04a59a43da9',
#   'Country': 'France',
#   'CountryCode': 'FR',
#   'Slug': 'france',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 11027112,
#   'NewDeaths': 0,
#   'TotalDeaths': 125797,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ed3c747a-ee72-4d5d-b2ee-ba9fb7905230',
#   'Country': 'Gabon',
#   'CountryCode': 'GA',
#   'Slug': 'gabon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 42640,
#   'NewDeaths': 0,
#   'TotalDeaths': 290,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e9c60bc9-1e37-4780-8e15-292f60464abc',
#   'Country': 'Gambia',
#   'CountryCode': 'GM',
#   'Slug': 'gambia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 10376,
#   'NewDeaths': 0,
#   'TotalDeaths': 343,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ef702e3d-0145-486a-9949-988e87efbbaa',
#   'Country': 'Georgia',
#   'CountryCode': 'GE',
#   'Slug': 'georgia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 945609,
#   'NewDeaths': 0,
#   'TotalDeaths': 14041,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '0bca1de6-7611-4179-855d-c003ee8ccea1',
#   'Country': 'Germany',
#   'CountryCode': 'DE',
#   'Slug': 'germany',
#   'NewConfirmed': 67337,
#   'TotalConfirmed': 7388045,
#   'NewDeaths': 444,
#   'TotalDeaths': 113373,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'd01f79fe-b6b9-42ab-9a59-7fe5350d81cd',
#   'Country': 'Ghana',
#   'CountryCode': 'GH',
#   'Slug': 'ghana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 148079,
#   'NewDeaths': 0,
#   'TotalDeaths': 1313,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'd348d838-9969-4e36-b134-8e512c320035',
#   'Country': 'Greece',
#   'CountryCode': 'GR',
#   'Slug': 'greece',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1388309,
#   'NewDeaths': 0,
#   'TotalDeaths': 21115,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f6583c13-bf82-420d-b6b1-1b0f90b2bcc4',
#   'Country': 'Grenada',
#   'CountryCode': 'GD',
#   'Slug': 'grenada',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7101,
#   'NewDeaths': 0,
#   'TotalDeaths': 200,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '5bfac20f-6af2-4347-b222-9cd74e93277c',
#   'Country': 'Guatemala',
#   'CountryCode': 'GT',
#   'Slug': 'guatemala',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 631730,
#   'NewDeaths': 0,
#   'TotalDeaths': 16114,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '05a2effb-d21f-4820-8fa5-4aa2f14e072f',
#   'Country': 'Guinea',
#   'CountryCode': 'GN',
#   'Slug': 'guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 33428,
#   'NewDeaths': 0,
#   'TotalDeaths': 393,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'fcc75cb9-4d39-4927-81bd-6ddf943cef9a',
#   'Country': 'Guinea-Bissau',
#   'CountryCode': 'GW',
#   'Slug': 'guinea-bissau',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6531,
#   'NewDeaths': 0,
#   'TotalDeaths': 149,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'eb321ca8-6d53-47d0-85b1-e5c6ebf874f5',
#   'Country': 'Guyana',
#   'CountryCode': 'GY',
#   'Slug': 'guyana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 41418,
#   'NewDeaths': 0,
#   'TotalDeaths': 1060,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'fd40832b-c0aa-4fcf-9cc7-ed1b228c45f5',
#   'Country': 'Haiti',
#   'CountryCode': 'HT',
#   'Slug': 'haiti',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 26259,
#   'NewDeaths': 0,
#   'TotalDeaths': 774,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'b8bb3249-fb08-4ceb-8652-3902473f6942',
#   'Country': 'Holy See (Vatican City State)',
#   'CountryCode': 'VA',
#   'Slug': 'holy-see-vatican-city-state',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 27,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '049177f1-7e11-4352-b4f1-63b6f28c9bbd',
#   'Country': 'Honduras',
#   'CountryCode': 'HN',
#   'Slug': 'honduras',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 379402,
#   'NewDeaths': 0,
#   'TotalDeaths': 10433,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '7b945ce2-4fde-407c-82ee-eae8deced102',
#   'Country': 'Hungary',
#   'CountryCode': 'HU',
#   'Slug': 'hungary',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1269979,
#   'NewDeaths': 0,
#   'TotalDeaths': 39599,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ddbd635e-42f1-49d8-a325-d60abd42a0d6',
#   'Country': 'Iceland',
#   'CountryCode': 'IS',
#   'Slug': 'iceland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 33901,
#   'NewDeaths': 0,
#   'TotalDeaths': 39,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'd5d6929f-7252-427f-ad9c-435376b2d3c0',
#   'Country': 'India',
#   'CountryCode': 'IN',
#   'Slug': 'india',
#   'NewConfirmed': 90928,
#   'TotalConfirmed': 35109286,
#   'NewDeaths': 325,
#   'TotalDeaths': 482876,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '0faca8ec-8e87-448c-af83-9d4f5b8a0d93',
#   'Country': 'Indonesia',
#   'CountryCode': 'ID',
#   'Slug': 'indonesia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4264136,
#   'NewDeaths': 0,
#   'TotalDeaths': 144109,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '8267f2f3-d51f-4a4c-b107-b7b2bbb8e5c1',
#   'Country': 'Iran, Islamic Republic of',
#   'CountryCode': 'IR',
#   'Slug': 'iran',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6201467,
#   'NewDeaths': 0,
#   'TotalDeaths': 131778,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '0d35b164-c3c9-4dd4-9895-eb8f5bb5529f',
#   'Country': 'Iraq',
#   'CountryCode': 'IQ',
#   'Slug': 'iraq',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2095183,
#   'NewDeaths': 0,
#   'TotalDeaths': 24191,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4d9badcc-5706-44d5-a29d-888606c2ef99',
#   'Country': 'Ireland',
#   'CountryCode': 'IE',
#   'Slug': 'ireland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 884855,
#   'NewDeaths': 0,
#   'TotalDeaths': 5952,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'eef6ee11-bafd-44a1-bcdb-ee52b6c96878',
#   'Country': 'Israel',
#   'CountryCode': 'IL',
#   'Slug': 'israel',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1429030,
#   'NewDeaths': 0,
#   'TotalDeaths': 8253,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f852b690-b567-448a-b590-d75e8924749c',
#   'Country': 'Italy',
#   'CountryCode': 'IT',
#   'Slug': 'italy',
#   'NewConfirmed': 189088,
#   'TotalConfirmed': 6756035,
#   'NewDeaths': 231,
#   'TotalDeaths': 138276,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '8d8b6317-f286-4f6a-9b41-62f2317d8c47',
#   'Country': 'Jamaica',
#   'CountryCode': 'JM',
#   'Slug': 'jamaica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 97066,
#   'NewDeaths': 0,
#   'TotalDeaths': 2483,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '03e0437f-0a30-46e3-97c2-c0530ae957c5',
#   'Country': 'Japan',
#   'CountryCode': 'JP',
#   'Slug': 'japan',
#   'NewConfirmed': 2490,
#   'TotalConfirmed': 1737540,
#   'NewDeaths': 1,
#   'TotalDeaths': 18394,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '3b769e50-0c4f-41da-b4bf-0cc91efcccb3',
#   'Country': 'Jordan',
#   'CountryCode': 'JO',
#   'Slug': 'jordan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1047953,
#   'NewDeaths': 0,
#   'TotalDeaths': 12372,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'b807dc80-263a-4c73-a6c8-fc89a92b6884',
#   'Country': 'Kazakhstan',
#   'CountryCode': 'KZ',
#   'Slug': 'kazakhstan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1074283,
#   'NewDeaths': 0,
#   'TotalDeaths': 18267,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '1204ca00-fda7-4d73-8e08-7beb612e6c5b',
#   'Country': 'Kenya',
#   'CountryCode': 'KE',
#   'Slug': 'kenya',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 304350,
#   'NewDeaths': 0,
#   'TotalDeaths': 5404,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '6661b505-bd74-421f-ad07-958afa3f829f',
#   'Country': 'Kiribati',
#   'CountryCode': 'KI',
#   'Slug': 'kiribati',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '23dae1a1-1430-432d-b071-df60834584f9',
#   'Country': 'Korea (South)',
#   'CountryCode': 'KR',
#   'Slug': 'korea-south',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 653792,
#   'NewDeaths': 0,
#   'TotalDeaths': 5887,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ebccb6a4-2a54-4390-912b-0c1a64169e0f',
#   'Country': 'Kuwait',
#   'CountryCode': 'KW',
#   'Slug': 'kuwait',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 423042,
#   'NewDeaths': 0,
#   'TotalDeaths': 2469,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '1c7124c2-2088-4a8e-8ec0-008be7621c99',
#   'Country': 'Kyrgyzstan',
#   'CountryCode': 'KG',
#   'Slug': 'kyrgyzstan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 185031,
#   'NewDeaths': 0,
#   'TotalDeaths': 2809,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4dbef75b-bf7c-424d-ab6f-d0b8f3056cc9',
#   'Country': 'Lao PDR',
#   'CountryCode': 'LA',
#   'Slug': 'lao-pdr',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 114787,
#   'NewDeaths': 0,
#   'TotalDeaths': 409,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'cd7b11af-dc84-4c51-8be0-4ade80eff125',
#   'Country': 'Latvia',
#   'CountryCode': 'LV',
#   'Slug': 'latvia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 281155,
#   'NewDeaths': 0,
#   'TotalDeaths': 4613,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '424a7399-a80e-48b4-90ea-8e6da1213cde',
#   'Country': 'Lebanon',
#   'CountryCode': 'LB',
#   'Slug': 'lebanon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 746632,
#   'NewDeaths': 0,
#   'TotalDeaths': 9213,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '82508303-3837-40c9-a2ad-76eac4f9e0f6',
#   'Country': 'Lesotho',
#   'CountryCode': 'LS',
#   'Slug': 'lesotho',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 29999,
#   'NewDeaths': 0,
#   'TotalDeaths': 673,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '6d109350-2647-49e8-a003-d5e689c210ce',
#   'Country': 'Liberia',
#   'CountryCode': 'LR',
#   'Slug': 'liberia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6851,
#   'NewDeaths': 0,
#   'TotalDeaths': 287,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e9dd4098-99a6-4c54-9d70-b363a101c3ca',
#   'Country': 'Libya',
#   'CountryCode': 'LY',
#   'Slug': 'libya',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 391633,
#   'NewDeaths': 0,
#   'TotalDeaths': 5752,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '8b4fded2-3ac0-454d-af4e-ab2ecbefa6a1',
#   'Country': 'Liechtenstein',
#   'CountryCode': 'LI',
#   'Slug': 'liechtenstein',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6406,
#   'NewDeaths': 0,
#   'TotalDeaths': 71,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '85cac20e-dd06-46a8-8f0b-93e9b907c227',
#   'Country': 'Lithuania',
#   'CountryCode': 'LT',
#   'Slug': 'lithuania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 529540,
#   'NewDeaths': 0,
#   'TotalDeaths': 7475,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '5cac88c3-cb81-4255-bb48-966ff38b49ae',
#   'Country': 'Luxembourg',
#   'CountryCode': 'LU',
#   'Slug': 'luxembourg',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 108366,
#   'NewDeaths': 0,
#   'TotalDeaths': 920,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4918b52f-bf4c-4bca-8a88-668a38b83127',
#   'Country': 'Macedonia, Republic of',
#   'CountryCode': 'MK',
#   'Slug': 'macedonia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 228540,
#   'NewDeaths': 0,
#   'TotalDeaths': 8000,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'fb50a7d8-7f35-4a6a-adee-0470b6c14461',
#   'Country': 'Madagascar',
#   'CountryCode': 'MG',
#   'Slug': 'madagascar',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 52434,
#   'NewDeaths': 0,
#   'TotalDeaths': 1067,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '8ecc2051-c034-493d-8421-a9b587d281b9',
#   'Country': 'Malawi',
#   'CountryCode': 'MW',
#   'Slug': 'malawi',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 77629,
#   'NewDeaths': 0,
#   'TotalDeaths': 2395,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '7674f0c6-5ee3-4560-88f5-b259a0100a6e',
#   'Country': 'Malaysia',
#   'CountryCode': 'MY',
#   'Slug': 'malaysia',
#   'NewConfirmed': 3270,
#   'TotalConfirmed': 2773156,
#   'NewDeaths': 18,
#   'TotalDeaths': 31609,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '35d37c66-8977-4565-95b4-ceddc914f91b',
#   'Country': 'Maldives',
#   'CountryCode': 'MV',
#   'Slug': 'maldives',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 96746,
#   'NewDeaths': 0,
#   'TotalDeaths': 263,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '778b44f5-eb24-4903-bf2f-55410dd6ba31',
#   'Country': 'Mali',
#   'CountryCode': 'ML',
#   'Slug': 'mali',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 22834,
#   'NewDeaths': 0,
#   'TotalDeaths': 670,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '43a9209e-2986-4809-8102-a5cc2601a5fd',
#   'Country': 'Malta',
#   'CountryCode': 'MT',
#   'Slug': 'malta',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 57131,
#   'NewDeaths': 0,
#   'TotalDeaths': 482,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a3c8297d-191a-4d13-b62e-fe7d31576c77',
#   'Country': 'Marshall Islands',
#   'CountryCode': 'MH',
#   'Slug': 'marshall-islands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '7cc30230-1ba8-4825-bd69-8a4edf2dff29',
#   'Country': 'Mauritania',
#   'CountryCode': 'MR',
#   'Slug': 'mauritania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 44646,
#   'NewDeaths': 0,
#   'TotalDeaths': 876,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'bf80279b-c340-4548-892c-a463c7c676fe',
#   'Country': 'Mauritius',
#   'CountryCode': 'MU',
#   'Slug': 'mauritius',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 23602,
#   'NewDeaths': 0,
#   'TotalDeaths': 240,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '110240d6-3af7-4f36-b4ad-e2275fa08c0b',
#   'Country': 'Mexico',
#   'CountryCode': 'MX',
#   'Slug': 'mexico',
#   'NewConfirmed': 20626,
#   'TotalConfirmed': 4029274,
#   'NewDeaths': 131,
#   'TotalDeaths': 299842,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '27527db3-0d6c-411d-9bdb-263d5d61d9f7',
#   'Country': 'Micronesia, Federated States of',
#   'CountryCode': 'FM',
#   'Slug': 'micronesia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '9f9f56f1-46f9-42c3-ad70-66d55d96481f',
#   'Country': 'Moldova',
#   'CountryCode': 'MD',
#   'Slug': 'moldova',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 378202,
#   'NewDeaths': 0,
#   'TotalDeaths': 10328,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a019ede2-6b51-4798-835a-b505b1698d91',
#   'Country': 'Monaco',
#   'CountryCode': 'MC',
#   'Slug': 'monaco',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5492,
#   'NewDeaths': 0,
#   'TotalDeaths': 41,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ce924794-50c4-4589-b581-7e9b22c803b0',
#   'Country': 'Mongolia',
#   'CountryCode': 'MN',
#   'Slug': 'mongolia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 391657,
#   'NewDeaths': 0,
#   'TotalDeaths': 2067,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '39e7d99a-f05e-48a3-8673-a7df414d788a',
#   'Country': 'Montenegro',
#   'CountryCode': 'ME',
#   'Slug': 'montenegro',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 180260,
#   'NewDeaths': 0,
#   'TotalDeaths': 2428,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '14b9e2e0-51e2-47cb-b67c-a31ed9559e0b',
#   'Country': 'Morocco',
#   'CountryCode': 'MA',
#   'Slug': 'morocco',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 977579,
#   'NewDeaths': 0,
#   'TotalDeaths': 14872,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'adc02423-0c1a-41e7-81fc-0ed88e5ab054',
#   'Country': 'Mozambique',
#   'CountryCode': 'MZ',
#   'Slug': 'mozambique',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 199940,
#   'NewDeaths': 0,
#   'TotalDeaths': 2050,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'd0d77b58-0b96-4257-bd2f-b4512e1d8cec',
#   'Country': 'Myanmar',
#   'CountryCode': 'MM',
#   'Slug': 'myanmar',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 531432,
#   'NewDeaths': 0,
#   'TotalDeaths': 19282,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e0ee1cd1-cbbf-4509-8b56-64ba8f7b16ac',
#   'Country': 'Namibia',
#   'CountryCode': 'NA',
#   'Slug': 'namibia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 150540,
#   'NewDeaths': 0,
#   'TotalDeaths': 3672,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'b13c876a-334f-4144-8d8e-f31b23ce4b52',
#   'Country': 'Nepal',
#   'CountryCode': 'NP',
#   'Slug': 'nepal',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 830002,
#   'NewDeaths': 0,
#   'TotalDeaths': 11601,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4cc6e969-bee6-4292-98d4-17d9a82d5916',
#   'Country': 'Netherlands',
#   'CountryCode': 'NL',
#   'Slug': 'netherlands',
#   'NewConfirmed': 24490,
#   'TotalConfirmed': 3223325,
#   'NewDeaths': 39,
#   'TotalDeaths': 21029,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4eb50ef2-1f9c-4e09-8952-0c818ec5fb55',
#   'Country': 'New Zealand',
#   'CountryCode': 'NZ',
#   'Slug': 'new-zealand',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 14469,
#   'NewDeaths': 0,
#   'TotalDeaths': 51,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'fa688a36-8645-4321-a886-6d38249297e4',
#   'Country': 'Nicaragua',
#   'CountryCode': 'NI',
#   'Slug': 'nicaragua',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17526,
#   'NewDeaths': 0,
#   'TotalDeaths': 218,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'de151caa-0e82-46bb-9ad7-1b68d30cf2d9',
#   'Country': 'Niger',
#   'CountryCode': 'NE',
#   'Slug': 'niger',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7590,
#   'NewDeaths': 0,
#   'TotalDeaths': 277,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'c59b6a2c-f047-4607-80fd-94df6fbf38f3',
#   'Country': 'Nigeria',
#   'CountryCode': 'NG',
#   'Slug': 'nigeria',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 245404,
#   'NewDeaths': 0,
#   'TotalDeaths': 3058,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '5bf4b634-7a85-42bc-846e-f04ec523cfd6',
#   'Country': 'Norway',
#   'CountryCode': 'NO',
#   'Slug': 'norway',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 420857,
#   'NewDeaths': 0,
#   'TotalDeaths': 1349,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'c8f0820e-bc4e-48f1-9fdb-129cb0c01b0a',
#   'Country': 'Oman',
#   'CountryCode': 'OM',
#   'Slug': 'oman',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 306492,
#   'NewDeaths': 0,
#   'TotalDeaths': 4117,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '8ca45152-d137-4e61-9849-59cf649de0bd',
#   'Country': 'Pakistan',
#   'CountryCode': 'PK',
#   'Slug': 'pakistan',
#   'NewConfirmed': 1085,
#   'TotalConfirmed': 1299848,
#   'NewDeaths': 5,
#   'TotalDeaths': 28955,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '07880336-dce9-4705-b295-13b5684894ad',
#   'Country': 'Palau',
#   'CountryCode': 'PW',
#   'Slug': 'palau',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '960421cd-6817-4095-8c47-7e76eeae98e9',
#   'Country': 'Palestinian Territory',
#   'CountryCode': 'PS',
#   'Slug': 'palestine',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 471414,
#   'NewDeaths': 0,
#   'TotalDeaths': 4954,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '3a0bd492-e75d-47b0-bb71-16718ee8d2e0',
#   'Country': 'Panama',
#   'CountryCode': 'PA',
#   'Slug': 'panama',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 503407,
#   'NewDeaths': 0,
#   'TotalDeaths': 7445,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '7a1081a2-0ce9-460a-af93-069e18e12e37',
#   'Country': 'Papua New Guinea',
#   'CountryCode': 'PG',
#   'Slug': 'papua-new-guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 36196,
#   'NewDeaths': 0,
#   'TotalDeaths': 590,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4e9d9105-ed3c-4133-aa26-50d9ddccbd44',
#   'Country': 'Paraguay',
#   'CountryCode': 'PY',
#   'Slug': 'paraguay',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 471434,
#   'NewDeaths': 0,
#   'TotalDeaths': 16653,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'c923bee8-9e06-473e-8bcc-fb660b213039',
#   'Country': 'Peru',
#   'CountryCode': 'PE',
#   'Slug': 'peru',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2309856,
#   'NewDeaths': 0,
#   'TotalDeaths': 202867,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '029189a9-b5c9-4a79-83e2-fc3fc091688d',
#   'Country': 'Philippines',
#   'CountryCode': 'PH',
#   'Slug': 'philippines',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2871745,
#   'NewDeaths': 0,
#   'TotalDeaths': 51662,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '61856f6e-d9dd-4b90-a43a-c3e9348fbf59',
#   'Country': 'Poland',
#   'CountryCode': 'PL',
#   'Slug': 'poland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4162715,
#   'NewDeaths': 0,
#   'TotalDeaths': 98666,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '1e246f23-9863-4cde-9e9b-40ce3fcf414c',
#   'Country': 'Portugal',
#   'CountryCode': 'PT',
#   'Slug': 'portugal',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1499976,
#   'NewDeaths': 0,
#   'TotalDeaths': 19029,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '9223faf8-7326-43c2-a9b8-47507dd7b5de',
#   'Country': 'Qatar',
#   'CountryCode': 'QA',
#   'Slug': 'qatar',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 257504,
#   'NewDeaths': 0,
#   'TotalDeaths': 618,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'abb716aa-319f-4627-aade-bfde4dd88c03',
#   'Country': 'Republic of Kosovo',
#   'CountryCode': 'XK',
#   'Slug': 'kosovo',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 161813,
#   'NewDeaths': 0,
#   'TotalDeaths': 2991,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '1137942d-bb76-4135-bf41-48127c7352fb',
#   'Country': 'Romania',
#   'CountryCode': 'RO',
#   'Slug': 'romania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1821849,
#   'NewDeaths': 0,
#   'TotalDeaths': 58896,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '01960a55-66e7-4e82-bb16-903120f38cbd',
#   'Country': 'Russian Federation',
#   'CountryCode': 'RU',
#   'Slug': 'russia',
#   'NewConfirmed': 15632,
#   'TotalConfirmed': 10405684,
#   'NewDeaths': 804,
#   'TotalDeaths': 306710,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'da38ccbb-7676-41df-8b30-942460ac2303',
#   'Country': 'Rwanda',
#   'CountryCode': 'RW',
#   'Slug': 'rwanda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 117123,
#   'NewDeaths': 0,
#   'TotalDeaths': 1362,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '8f6b1527-f912-41cc-93e5-5e3d2f913369',
#   'Country': 'Saint Kitts and Nevis',
#   'CountryCode': 'KN',
#   'Slug': 'saint-kitts-and-nevis',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 3489,
#   'NewDeaths': 0,
#   'TotalDeaths': 28,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'c085e510-a14d-4050-ad03-a36258818eb4',
#   'Country': 'Saint Lucia',
#   'CountryCode': 'LC',
#   'Slug': 'saint-lucia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 13974,
#   'NewDeaths': 0,
#   'TotalDeaths': 305,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a4a1005a-df8a-4e3f-af8c-ab1d8db67de7',
#   'Country': 'Saint Vincent and Grenadines',
#   'CountryCode': 'VC',
#   'Slug': 'saint-vincent-and-the-grenadines',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 6039,
#   'NewDeaths': 0,
#   'TotalDeaths': 83,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '977182e4-3eb4-4807-87e5-298c96c07105',
#   'Country': 'Samoa',
#   'CountryCode': 'WS',
#   'Slug': 'samoa',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 3,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '577e1b9e-f310-4ca5-9e9a-c96c5bc38327',
#   'Country': 'San Marino',
#   'CountryCode': 'SM',
#   'Slug': 'san-marino',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8847,
#   'NewDeaths': 0,
#   'TotalDeaths': 103,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '572c36f6-fd13-443c-a499-90bf6a55ea23',
#   'Country': 'Sao Tome and Principe',
#   'CountryCode': 'ST',
#   'Slug': 'sao-tome-and-principe',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4034,
#   'NewDeaths': 0,
#   'TotalDeaths': 61,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a91d3924-8b6c-4b65-ae31-3157d3a9d13e',
#   'Country': 'Saudi Arabia',
#   'CountryCode': 'SA',
#   'Slug': 'saudi-arabia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 565482,
#   'NewDeaths': 0,
#   'TotalDeaths': 8886,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e60620a4-837d-4111-9de0-262b0cd1c160',
#   'Country': 'Senegal',
#   'CountryCode': 'SN',
#   'Slug': 'senegal',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 76753,
#   'NewDeaths': 0,
#   'TotalDeaths': 1892,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '76af6df9-f55c-48ec-9496-0dd3a937eeb3',
#   'Country': 'Serbia',
#   'CountryCode': 'RS',
#   'Slug': 'serbia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1318333,
#   'NewDeaths': 0,
#   'TotalDeaths': 12831,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a55ccb52-c8b4-479c-a435-1c4478c9db61',
#   'Country': 'Seychelles',
#   'CountryCode': 'SC',
#   'Slug': 'seychelles',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 26255,
#   'NewDeaths': 0,
#   'TotalDeaths': 134,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '8e045411-e793-405f-97b7-0122750955a3',
#   'Country': 'Sierra Leone',
#   'CountryCode': 'SL',
#   'Slug': 'sierra-leone',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7308,
#   'NewDeaths': 0,
#   'TotalDeaths': 123,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a4ec628c-4ea7-47ec-89b6-15e25825685a',
#   'Country': 'Singapore',
#   'CountryCode': 'SG',
#   'Slug': 'singapore',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 282401,
#   'NewDeaths': 0,
#   'TotalDeaths': 834,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'daa48f11-5cb8-4f3b-9c6f-d07899f6fa37',
#   'Country': 'Slovakia',
#   'CountryCode': 'SK',
#   'Slug': 'slovakia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1385760,
#   'NewDeaths': 0,
#   'TotalDeaths': 16824,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '7bf94a45-b726-4121-8856-f395ad3be7a4',
#   'Country': 'Slovenia',
#   'CountryCode': 'SI',
#   'Slug': 'slovenia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 475027,
#   'NewDeaths': 0,
#   'TotalDeaths': 5629,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a0275801-78db-4a94-8aa7-3026a6236c22',
#   'Country': 'Solomon Islands',
#   'CountryCode': 'SB',
#   'Slug': 'solomon-islands',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 24,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'b2a80fdf-bb08-4c1c-ae9b-69cc60249c64',
#   'Country': 'Somalia',
#   'CountryCode': 'SO',
#   'Slug': 'somalia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 24261,
#   'NewDeaths': 0,
#   'TotalDeaths': 1335,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a70c9030-cb6e-47a7-80b9-b1a0cb097504',
#   'Country': 'South Africa',
#   'CountryCode': 'ZA',
#   'Slug': 'south-africa',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 3494696,
#   'NewDeaths': 0,
#   'TotalDeaths': 91561,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '05274dbf-4065-450c-8905-025c51631818',
#   'Country': 'South Sudan',
#   'CountryCode': 'SS',
#   'Slug': 'south-sudan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 15849,
#   'NewDeaths': 0,
#   'TotalDeaths': 136,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '3b4739b5-c9ee-4357-8c98-83a160984ed9',
#   'Country': 'Spain',
#   'CountryCode': 'ES',
#   'Slug': 'spain',
#   'NewConfirmed': 137180,
#   'TotalConfirmed': 6922466,
#   'NewDeaths': 148,
#   'TotalDeaths': 89837,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '0925f578-df88-4c8d-9b5e-a5d3673bff80',
#   'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Slug': 'sri-lanka',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 589479,
#   'NewDeaths': 0,
#   'TotalDeaths': 15065,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ede99604-7c45-4365-ba3b-744c5a19b33a',
#   'Country': 'Sudan',
#   'CountryCode': 'SD',
#   'Slug': 'sudan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 47272,
#   'NewDeaths': 0,
#   'TotalDeaths': 3340,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e73aac2f-6f19-4252-8892-5e3ead291b17',
#   'Country': 'Suriname',
#   'CountryCode': 'SR',
#   'Slug': 'suriname',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 55376,
#   'NewDeaths': 0,
#   'TotalDeaths': 1193,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '82e13276-cba2-459b-a659-03659ab7a796',
#   'Country': 'Swaziland',
#   'CountryCode': 'SZ',
#   'Slug': 'swaziland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 66873,
#   'NewDeaths': 0,
#   'TotalDeaths': 1320,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e3dfc40a-3f3d-4723-8330-07f86b1b3994',
#   'Country': 'Sweden',
#   'CountryCode': 'SE',
#   'Slug': 'sweden',
#   'NewConfirmed': 17514,
#   'TotalConfirmed': 1375267,
#   'NewDeaths': 39,
#   'TotalDeaths': 15369,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a4124ece-2229-4746-acb1-688cccec6dee',
#   'Country': 'Switzerland',
#   'CountryCode': 'CH',
#   'Slug': 'switzerland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1422932,
#   'NewDeaths': 0,
#   'TotalDeaths': 12303,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '1a4269a3-d7e4-49e1-94f6-55e73f08e0cf',
#   'Country': 'Syrian Arab Republic (Syria)',
#   'CountryCode': 'SY',
#   'Slug': 'syria',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 50417,
#   'NewDeaths': 0,
#   'TotalDeaths': 2915,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '1680e2a9-8754-4802-bb4f-a6bfc1807465',
#   'Country': 'Taiwan, Republic of China',
#   'CountryCode': 'TW',
#   'Slug': 'taiwan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17155,
#   'NewDeaths': 0,
#   'TotalDeaths': 850,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '7443bbef-21dd-4f49-93d9-72f9b84d48a0',
#   'Country': 'Tajikistan',
#   'CountryCode': 'TJ',
#   'Slug': 'tajikistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 17493,
#   'NewDeaths': 0,
#   'TotalDeaths': 125,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4eaf5eae-7c5a-4781-a289-f1de56e00618',
#   'Country': 'Tanzania, United Republic of',
#   'CountryCode': 'TZ',
#   'Slug': 'tanzania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 30564,
#   'NewDeaths': 0,
#   'TotalDeaths': 740,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '3c41a9b5-deff-4147-b900-33d128d9d6ab',
#   'Country': 'Thailand',
#   'CountryCode': 'TH',
#   'Slug': 'thailand',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2235576,
#   'NewDeaths': 0,
#   'TotalDeaths': 21750,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'd9ead2a0-9955-4866-b683-3a9128b45ff6',
#   'Country': 'Timor-Leste',
#   'CountryCode': 'TL',
#   'Slug': 'timor-leste',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 19842,
#   'NewDeaths': 0,
#   'TotalDeaths': 122,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'ec8cfe90-3dd0-411b-8d8a-ef25d457b2f7',
#   'Country': 'Togo',
#   'CountryCode': 'TG',
#   'Slug': 'togo',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 32515,
#   'NewDeaths': 0,
#   'TotalDeaths': 251,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '3a68069e-2cbd-49b8-9252-177d4f0a2bc9',
#   'Country': 'Tonga',
#   'CountryCode': 'TO',
#   'Slug': 'tonga',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4d6ebc5d-a8b4-4e00-89bd-61f658c4d837',
#   'Country': 'Trinidad and Tobago',
#   'CountryCode': 'TT',
#   'Slug': 'trinidad-and-tobago',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 94213,
#   'NewDeaths': 0,
#   'TotalDeaths': 2973,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '4a2f2821-a9ca-4f70-b53d-99cf10f3b451',
#   'Country': 'Tunisia',
#   'CountryCode': 'TN',
#   'Slug': 'tunisia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 733379,
#   'NewDeaths': 0,
#   'TotalDeaths': 25617,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'a9f567a8-d3ed-48f5-b4d7-977637bada38',
#   'Country': 'Turkey',
#   'CountryCode': 'TR',
#   'Slug': 'turkey',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 9720831,
#   'NewDeaths': 0,
#   'TotalDeaths': 83075,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'e8f454e0-bbf5-445f-96b8-509a4cbb17bb',
#   'Country': 'Uganda',
#   'CountryCode': 'UG',
#   'Slug': 'uganda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 148609,
#   'NewDeaths': 0,
#   'TotalDeaths': 3313,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'f8b39b96-4ee7-4523-a255-3df7bd3c3946',
#   'Country': 'Ukraine',
#   'CountryCode': 'UA',
#   'Slug': 'ukraine',
#   'NewConfirmed': 4711,
#   'TotalConfirmed': 3862959,
#   'NewDeaths': 297,
#   'TotalDeaths': 103014,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '29242946-6d9a-42ed-8b34-9253af9d1887',
#   'Country': 'United Arab Emirates',
#   'CountryCode': 'AE',
#   'Slug': 'united-arab-emirates',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 774897,
#   'NewDeaths': 0,
#   'TotalDeaths': 2170,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '934ff0fa-6a52-4144-8544-766d70165b9a',
#   'Country': 'United Kingdom',
#   'CountryCode': 'GB',
#   'Slug': 'united-kingdom',
#   'NewConfirmed': 195235,
#   'TotalConfirmed': 13918510,
#   'NewDeaths': 344,
#   'TotalDeaths': 149761,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '522b0b28-db35-4183-8ab5-10fce095ea9f',
#   'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Slug': 'united-states',
#   'NewConfirmed': 642139,
#   'TotalConfirmed': 57700873,
#   'NewDeaths': 1986,
#   'TotalDeaths': 832118,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '8bcd3bf9-5ade-4ae8-8983-ee6d23766e89',
#   'Country': 'Uruguay',
#   'CountryCode': 'UY',
#   'Slug': 'uruguay',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 425436,
#   'NewDeaths': 0,
#   'TotalDeaths': 6181,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'd88c0b38-613c-4b01-a017-015c48166ad2',
#   'Country': 'Uzbekistan',
#   'CountryCode': 'UZ',
#   'Slug': 'uzbekistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 199361,
#   'NewDeaths': 0,
#   'TotalDeaths': 1485,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '079375f7-fb0b-4166-b1bd-5f830ea57ad3',
#   'Country': 'Vanuatu',
#   'CountryCode': 'VU',
#   'Slug': 'vanuatu',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 7,
#   'NewDeaths': 0,
#   'TotalDeaths': 1,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'dc9c2457-b1c9-4dd4-b2cc-99915dfacb34',
#   'Country': 'Venezuela (Bolivarian Republic)',
#   'CountryCode': 'VE',
#   'Slug': 'venezuela',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 445680,
#   'NewDeaths': 0,
#   'TotalDeaths': 5341,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': 'dca40048-729d-4a86-8844-a693d47a0c99',
#   'Country': 'Viet Nam',
#   'CountryCode': 'VN',
#   'Slug': 'vietnam',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1817721,
#   'NewDeaths': 0,
#   'TotalDeaths': 33475,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '88e3c666-f05b-412a-934b-cee4040ef1f8',
#   'Country': 'Yemen',
#   'CountryCode': 'YE',
#   'Slug': 'yemen',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 10146,
#   'NewDeaths': 0,
#   'TotalDeaths': 1985,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '80290efe-990a-4a0f-a6e5-88a8e892a4cd',
#   'Country': 'Zambia',
#   'CountryCode': 'ZM',
#   'Slug': 'zambia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 269991,
#   'NewDeaths': 0,
#   'TotalDeaths': 3772,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}},
#  {'ID': '71b790f9-4642-4654-8938-fb91290ca601',
#   'Country': 'Zimbabwe',
#   'CountryCode': 'ZW',
#   'Slug': 'zimbabwe',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 219057,
#   'NewDeaths': 0,
#   'TotalDeaths': 5092,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2022-01-06T17:55:36.399Z',
#   'Premium': {}}]

# %% [markdown]
# This will loop through the list of dictionaries, extracting the values from the ‘Country’ and ‘TotalConfirmed’ keys from each dictionary into a list, and then adding this resulting list to our country_list

# %%
country_list = []
for country_info in response_info['Countries']:
 country_list.append([country_info['Country'], country_info['TotalConfirmed']])

# %%
country_list
# Out:
# [['Afghanistan', 158245],
#  ['Albania', 212021],
#  ['Algeria', 220415],
#  ['Andorra', 25289],
#  ['Angola', 86636],
#  ['Antigua and Barbuda', 4486],
#  ['Argentina', 5915695],
#  ['Armenia', 345255],
#  ['Australia', 684229],
#  ['Austria', 1304086],
#  ['Azerbaijan', 618918],
#  ['Bahamas', 26326],
#  ['Bahrain', 286529],
#  ['Bangladesh', 1588807],
#  ['Barbados', 30177],
#  ['Belarus', 703507],
#  ['Belgium', 2179710],
#  ['Belize', 34628],
#  ['Benin', 25522],
#  ['Bhutan', 2669],
#  ['Bolivia', 631554],
#  ['Bosnia and Herzegovina', 295240],
#  ['Botswana', 222053],
#  ['Brazil', 22328252],
#  ['Brunei Darussalam', 15532],
#  ['Bulgaria', 764476],
#  ['Burkina Faso', 18637],
#  ['Burundi', 32076],
#  ['Cambodia', 120535],
#  ['Cameroon', 109367],
#  ['Canada', 2010366],
#  ['Cape Verde', 45989],
#  ['Central African Republic', 12454],
#  ['Chad', 6185],
#  ['Chile', 1814188],
#  ['China', 115908],
#  ['Colombia', 5219633],
#  ['Comoros', 7283],
#  ['Congo (Brazzaville)', 21277],
#  ['Congo (Kinshasa)', 79942],
#  ['Costa Rica', 578413],
#  ['Croatia', 736486],
#  ['Cuba', 969138],
#  ['Cyprus', 188380],
#  ['Czech Republic', 2503374],
#  ["Côte d'Ivoire", 75064],
#  ['Denmark', 903652],
#  ['Djibouti', 13839],
#  ['Dominica', 7073],
#  ['Dominican Republic', 433710],
#  ['Ecuador', 553201],
#  ['Egypt', 389454],
#  ['El Salvador', 122063],
#  ['Equatorial Guinea', 13876],
#  ['Eritrea', 8161],
#  ['Estonia', 246221],
#  ['Ethiopia', 436586],
#  ['Fiji', 55649],
#  ['Finland', 289622],
#  ['France', 11027112],
#  ['Gabon', 42640],
#  ['Gambia', 10376],
#  ['Georgia', 945609],
#  ['Germany', 7388045],
#  ['Ghana', 148079],
#  ['Greece', 1388309],
#  ['Grenada', 7101],
#  ['Guatemala', 631730],
#  ['Guinea', 33428],
#  ['Guinea-Bissau', 6531],
#  ['Guyana', 41418],
#  ['Haiti', 26259],
#  ['Holy See (Vatican City State)', 27],
#  ['Honduras', 379402],
#  ['Hungary', 1269979],
#  ['Iceland', 33901],
#  ['India', 35109286],
#  ['Indonesia', 4264136],
#  ['Iran, Islamic Republic of', 6201467],
#  ['Iraq', 2095183],
#  ['Ireland', 884855],
#  ['Israel', 1429030],
#  ['Italy', 6756035],
#  ['Jamaica', 97066],
#  ['Japan', 1737540],
#  ['Jordan', 1047953],
#  ['Kazakhstan', 1074283],
#  ['Kenya', 304350],
#  ['Kiribati', 2],
#  ['Korea (South)', 653792],
#  ['Kuwait', 423042],
#  ['Kyrgyzstan', 185031],
#  ['Lao PDR', 114787],
#  ['Latvia', 281155],
#  ['Lebanon', 746632],
#  ['Lesotho', 29999],
#  ['Liberia', 6851],
#  ['Libya', 391633],
#  ['Liechtenstein', 6406],
#  ['Lithuania', 529540],
#  ['Luxembourg', 108366],
#  ['Macedonia, Republic of', 228540],
#  ['Madagascar', 52434],
#  ['Malawi', 77629],
#  ['Malaysia', 2773156],
#  ['Maldives', 96746],
#  ['Mali', 22834],
#  ['Malta', 57131],
#  ['Marshall Islands', 4],
#  ['Mauritania', 44646],
#  ['Mauritius', 23602],
#  ['Mexico', 4029274],
#  ['Micronesia, Federated States of', 1],
#  ['Moldova', 378202],
#  ['Monaco', 5492],
#  ['Mongolia', 391657],
#  ['Montenegro', 180260],
#  ['Morocco', 977579],
#  ['Mozambique', 199940],
#  ['Myanmar', 531432],
#  ['Namibia', 150540],
#  ['Nepal', 830002],
#  ['Netherlands', 3223325],
#  ['New Zealand', 14469],
#  ['Nicaragua', 17526],
#  ['Niger', 7590],
#  ['Nigeria', 245404],
#  ['Norway', 420857],
#  ['Oman', 306492],
#  ['Pakistan', 1299848],
#  ['Palau', 8],
#  ['Palestinian Territory', 471414],
#  ['Panama', 503407],
#  ['Papua New Guinea', 36196],
#  ['Paraguay', 471434],
#  ['Peru', 2309856],
#  ['Philippines', 2871745],
#  ['Poland', 4162715],
#  ['Portugal', 1499976],
#  ['Qatar', 257504],
#  ['Republic of Kosovo', 161813],
#  ['Romania', 1821849],
#  ['Russian Federation', 10405684],
#  ['Rwanda', 117123],
#  ['Saint Kitts and Nevis', 3489],
#  ['Saint Lucia', 13974],
#  ['Saint Vincent and Grenadines', 6039],
#  ['Samoa', 3],
#  ['San Marino', 8847],
#  ['Sao Tome and Principe', 4034],
#  ['Saudi Arabia', 565482],
#  ['Senegal', 76753],
#  ['Serbia', 1318333],
#  ['Seychelles', 26255],
#  ['Sierra Leone', 7308],
#  ['Singapore', 282401],
#  ['Slovakia', 1385760],
#  ['Slovenia', 475027],
#  ['Solomon Islands', 24],
#  ['Somalia', 24261],
#  ['South Africa', 3494696],
#  ['South Sudan', 15849],
#  ['Spain', 6922466],
#  ['Sri Lanka', 589479],
#  ['Sudan', 47272],
#  ['Suriname', 55376],
#  ['Swaziland', 66873],
#  ['Sweden', 1375267],
#  ['Switzerland', 1422932],
#  ['Syrian Arab Republic (Syria)', 50417],
#  ['Taiwan, Republic of China', 17155],
#  ['Tajikistan', 17493],
#  ['Tanzania, United Republic of', 30564],
#  ['Thailand', 2235576],
#  ['Timor-Leste', 19842],
#  ['Togo', 32515],
#  ['Tonga', 1],
#  ['Trinidad and Tobago', 94213],
#  ['Tunisia', 733379],
#  ['Turkey', 9720831],
#  ['Uganda', 148609],
#  ['Ukraine', 3862959],
#  ['United Arab Emirates', 774897],
#  ['United Kingdom', 13918510],
#  ['United States of America', 57700873],
#  ['Uruguay', 425436],
#  ['Uzbekistan', 199361],
#  ['Vanuatu', 7],
#  ['Venezuela (Bolivarian Republic)', 445680],
#  ['Viet Nam', 1817721],
#  ['Yemen', 10146],
#  ['Zambia', 269991],
#  ['Zimbabwe', 219057]]

# %%
import pandas as pd
country_df = pd.DataFrame(data=country_list, columns=['Country', 'Total_Confirmed'])

# %%
country_df.head(10)
# Out:
#                Country  Total_Confirmed
# 0          Afghanistan           158245
# 1              Albania           212021
# 2              Algeria           220415
# 3              Andorra            25289
# 4               Angola            86636
# 5  Antigua and Barbuda             4486
# 6            Argentina          5915695
# 7              Armenia           345255
# 8            Australia           684229
# 9              Austria          1304086

# %% [markdown]
# ### This can be proceeded with visualization or connection to other storage bucket for further analysis
